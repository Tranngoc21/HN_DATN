# %% [markdown]
# ### Xây dựng và huấn luyện mô hình CNN 1D

# %% [markdown]
# #### Chuẩn bị dữ liệu

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('Data/data_preprocessing.csv', index_col='Date', parse_dates=True)
df.head()
# Out:
#             Precipitation  Temperature  Relative Humidity  Wind Speed
# Date
# 1985-01-01            0.0        24.12              66.46       26.87
# 1985-01-02            0.0        24.27              66.08       26.60
# 1985-01-03            0.1        25.02              61.42       22.44
# 1985-01-04            0.2        25.26              60.54       22.89
# 1985-01-05            0.0        25.05              59.92       24.88

# %%
# Sắp xếp và kiểm tra dữ liệu
df = df.sort_index()

# kiểm tra liên tục thời gian
print(df.index.to_series().diff().value_counts().head())
# Out:
# Date
# 1 days    12204
# Name: count, dtype: int64

# %%
# Chọn biến đầu vào & mục tiêu
features = ['Precipitation', 'Relative Humidity', 'Wind Speed']
target = 'Temperature'

X = df[features]
y = df[target]

# %%
# Chia tập dữ liệu: 70% train, 15% validation, 15% test
total_samples = len(X)
train_size = int(total_samples * 0.70)
val_size = int(total_samples * 0.15)

X_train = X[:train_size]
y_train = y[:train_size]

X_val = X[train_size:train_size + val_size]
y_val = y[train_size:train_size + val_size]

X_test = X[train_size + val_size:]
y_test = y[train_size + val_size:]

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_val shape:", X_val.shape)
print("y_val shape:", y_val.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (8543, 3)
# y_train shape: (8543,)
# X_val shape: (1830, 3)
# y_val shape: (1830,)
# X_test shape: (1832, 3)
# y_test shape: (1832,)

# %%
# Chuẩn hóa dữ liệu
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
X_val_scaled   = scaler_X.transform(X_val)
X_test_scaled  = scaler_X.transform(X_test)

y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1,1))
y_val_scaled   = scaler_y.transform(y_val.values.reshape(-1,1))
y_test_scaled  = scaler_y.transform(y_test.values.reshape(-1,1))

# %%
# Hàm tạo chuỗi dữ liệu > Dự đoán ngày tiếp theo
def create_sequences(X, y, time_step):
    X_seq, y_seq = [], []
    
    for i in range(len(X) - time_step):
        X_seq.append(X[i:i + time_step])
        y_seq.append(y[i + time_step])
        
    return np.array(X_seq), np.array(y_seq)

# %%
# Xác định time_step = 30 
time_step = 30

X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_scaled, time_step)
X_val_seq, y_val_seq     = create_sequences(X_val_scaled, y_val_scaled, time_step)
X_test_seq, y_test_seq   = create_sequences(X_test_scaled, y_test_scaled, time_step)

# %% [markdown]
# ### Xây dựng mô hình

# %%
# Khai báo thư viện
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
print("X_train_seq shape:", X_train_seq.shape)
# Out:
# X_train_seq shape: (8513, 30, 3)

# %%
# Xây dựng mô hình CNN 1D với Input layer đúng chuẩn
model = Sequential([
    Input(shape=(X_train_seq.shape[1], X_train_seq.shape[2])),
    Conv1D(filters=64, kernel_size=2, activation='relu'),
    MaxPooling1D(pool_size=2),
    Flatten(),
    Dense(50, activation='relu'),
    Dense(1)
])

# %%
# Biên dịch mô hình
model.compile(optimizer='adam',
              loss='mse',
              metrics=['mae'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 29, 64)              │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 14, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 896)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 50)                  │          44,850 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 45,349 (177.14 KB)
#  Trainable params: 45,349 (177.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
print(np.isnan(X_train_seq).sum())
print(np.isnan(y_train_seq).sum())
# Out:
# 0
# 0

# %% [markdown]
# #### Huấn luyện mô hình

# %%
# Huấn luyện mô hình CNN-1D với epochs=50, batch_size=32 
history = model.fit(
    X_train_seq, y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=50,
    batch_size=32
)
# Out:
# Epoch 1/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0235 - mae: 0.1155 - val_loss: 0.0156 - val_mae: 0.1025
# Epoch 2/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0109 - mae: 0.0819 - val_loss: 0.0074 - val_mae: 0.0680
# Epoch 3/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0102 - mae: 0.0788 - val_loss: 0.0115 - val_mae: 0.0876
# Epoch 4/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - mae: 0.0756 - val_loss: 0.0066 - val_mae: 0.0647
# Epoch 5/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - mae: 0.0759 - val_loss: 0.0105 - val_mae: 0.0828
# Epoch 6/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0092 - mae: 0.0753 - val_loss: 0.0067 - val_mae: 0.0651
# Epoch 7/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0091 - mae: 0.0744 - val_loss: 0.0077 - val_mae: 0.0702
# Epoch 8/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0090 - mae: 0.0741 - val_loss: 0.0067 - val_mae: 0.0644
# Epoch 9/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0088 - mae: 0.0734 - val_loss: 0.0102 - val_mae: 0.0813
# Epoch 10/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0087 - mae: 0.0728 - val_loss: 0.0084 - val_mae: 0.0729
# Epoch 11/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0089 - mae: 0.0742 - val_loss: 0.0068 - val_mae: 0.0656
# Epoch 12/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0088 - mae: 0.0733 - val_loss: 0.0080 - val_mae: 0.0717
# Epoch 13/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0085 - mae: 0.0724 - val_loss: 0.0068 - val_mae: 0.0655
# Epoch 14/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0085 - mae: 0.0720 - val_loss: 0.0068 - val_mae: 0.0651
# Epoch 15/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0088 - mae: 0.0738 - val_loss: 0.0070 - val_mae: 0.0662
# Epoch 16/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0084 - mae: 0.0715 - val_loss: 0.0078 - val_mae: 0.0697
# Epoch 17/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0082 - mae: 0.0707 - val_loss: 0.0085 - val_mae: 0.0731
# Epoch 18/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081 - mae: 0.0704 - val_loss: 0.0091 - val_mae: 0.0762
# Epoch 19/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0082 - mae: 0.0707 - val_loss: 0.0089 - val_mae: 0.0749
# Epoch 20/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0080 - mae: 0.0701 - val_loss: 0.0091 - val_mae: 0.0754
# Epoch 21/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0080 - mae: 0.0698 - val_loss: 0.0075 - val_mae: 0.0689
# Epoch 22/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081 - mae: 0.0705 - val_loss: 0.0072 - val_mae: 0.0672
# Epoch 23/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079 - mae: 0.0691 - val_loss: 0.0103 - val_mae: 0.0812
# Epoch 24/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079 - mae: 0.0695 - val_loss: 0.0073 - val_mae: 0.0683
# Epoch 25/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0078 - mae: 0.0691 - val_loss: 0.0071 - val_mae: 0.0666
# Epoch 26/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079 - mae: 0.0695 - val_loss: 0.0098 - val_mae: 0.0800
# Epoch 27/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0080 - mae: 0.0698 - val_loss: 0.0084 - val_mae: 0.0733
# Epoch 28/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0076 - mae: 0.0680 - val_loss: 0.0070 - val_mae: 0.0663
# Epoch 29/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0074 - mae: 0.0677 - val_loss: 0.0106 - val_mae: 0.0830
# Epoch 30/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0077 - mae: 0.0684 - val_loss: 0.0070 - val_mae: 0.0665
# Epoch 31/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0074 - mae: 0.0672 - val_loss: 0.0073 - val_mae: 0.0682
# Epoch 32/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0073 - mae: 0.0669 - val_loss: 0.0079 - val_mae: 0.0711
# Epoch 33/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0071 - mae: 0.0661 - val_loss: 0.0096 - val_mae: 0.0788
# Epoch 34/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0071 - mae: 0.0661 - val_loss: 0.0070 - val_mae: 0.0662
# Epoch 35/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0071 - mae: 0.0661 - val_loss: 0.0076 - val_mae: 0.0695
# Epoch 36/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0071 - mae: 0.0659 - val_loss: 0.0120 - val_mae: 0.0897
# Epoch 37/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0071 - mae: 0.0657 - val_loss: 0.0088 - val_mae: 0.0750
# Epoch 38/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0069 - mae: 0.0651 - val_loss: 0.0071 - val_mae: 0.0675
# Epoch 39/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0068 - mae: 0.0646 - val_loss: 0.0076 - val_mae: 0.0699
# Epoch 40/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0068 - mae: 0.0645 - val_loss: 0.0139 - val_mae: 0.0972
# Epoch 41/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0065 - mae: 0.0632 - val_loss: 0.0087 - val_mae: 0.0742
# Epoch 42/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0066 - mae: 0.0635 - val_loss: 0.0089 - val_mae: 0.0744
# Epoch 43/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0064 - mae: 0.0627 - val_loss: 0.0072 - val_mae: 0.0681
# Epoch 44/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0066 - mae: 0.0634 - val_loss: 0.0144 - val_mae: 0.0976
# Epoch 45/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0065 - mae: 0.0631 - val_loss: 0.0080 - val_mae: 0.0713
# Epoch 46/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0062 - mae: 0.0616 - val_loss: 0.0081 - val_mae: 0.0718
# Epoch 47/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0062 - mae: 0.0614 - val_loss: 0.0084 - val_mae: 0.0726
# Epoch 48/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0061 - mae: 0.0610 - val_loss: 0.0077 - val_mae: 0.0696
# Epoch 49/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0062 - mae: 0.0616 - val_loss: 0.0102 - val_mae: 0.0811
# Epoch 50/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0060 - mae: 0.0603 - val_loss: 0.0082 - val_mae: 0.0718

# %% [markdown]
# #### Kiểm tra dữ liệu

# %%
# Dự đoán trên tập TEST
y_pred_scaled = model.predict(X_test_seq)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Đưa về giá trị gốc (inverse transform)
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_test_original = scaler_y.inverse_transform(y_test_seq)

# %%
# Đánh giá bằng các chỉ số Regression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

mse = mean_squared_error(y_test_original, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_original, y_pred)
r2 = r2_score(y_test_original, y_pred)

print("MSE :", mse)
print("RMSE:", rmse)
print("MAE :", mae)
print("R2  :", r2)
# Out:
# MSE : 1.5101225180704085
# RMSE: 1.2288704236291181
# MAE : 0.93881113168799
# R2  : 0.4343138857066411

# %%
# Vẽ biểu đồ so sánh Thực tế vs Dự đoán
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(y_test_original[:200], label="Actual")
plt.plot(y_pred[:200], label="Predicted")
plt.legend()
plt.title("So sánh nhiệt độ thực tế và dự đoán")
plt.show()

# %%
# Vẽ biểu đồ Loss trong quá trình train
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.title("Training vs Validation Loss")
plt.show()

# %%
print("===== KẾT QUẢ ĐÁNH GIÁ MÔ HÌNH =====")
print(f"Sai số bình phương trung bình (MSE): {mse:.4f}")
print(f"Căn bậc hai sai số (RMSE): {rmse:.4f} °C")
print(f"Sai số tuyệt đối trung bình (MAE): {mae:.4f} °C")
print(f"Hệ số xác định (R²): {r2:.4f}")
# Out:
# ===== KẾT QUẢ ĐÁNH GIÁ MÔ HÌNH =====
# Sai số bình phương trung bình (MSE): 1.5101
# Căn bậc hai sai số (RMSE): 1.2289 °C
# Sai số tuyệt đối trung bình (MAE): 0.9388 °C
# Hệ số xác định (R²): 0.4343

# %%
comparison_df = pd.DataFrame({
    "Nhiệt độ thực tế (°C)": y_test_original.flatten(),
    "Nhiệt độ dự đoán (°C)": y_pred.flatten()
})

comparison_df["Sai số"] = comparison_df["Nhiệt độ thực tế (°C)"] - comparison_df["Nhiệt độ dự đoán (°C)"]
comparison_df["Sai số tuyệt đối"] = comparison_df["Sai số"].abs()

print("===== BẢNG SO SÁNH GIÁ TRỊ THỰC TẾ VÀ DỰ ĐOÁN =====")
display(comparison_df.round(2).head(10))
# Out:
# ===== BẢNG SO SÁNH GIÁ TRỊ THỰC TẾ VÀ DỰ ĐOÁN =====
#    Nhiệt độ thực tế (°C)  Nhiệt độ dự đoán (°C)  Sai số  Sai số tuyệt đối
# 0                  26.93              27.230000   -0.30              0.30
# 1                  28.02              28.440001   -0.42              0.42
# 2                  27.49              28.080000   -0.59              0.59
# 3                  28.11              28.200001   -0.09              0.09
# 4                  28.19              28.209999   -0.02              0.02
# 5                  27.71              28.100000   -0.39              0.39
# 6                  28.26              27.850000    0.41              0.41
# 7                  28.12              27.879999    0.24              0.24
# 8                  27.66              28.459999   -0.80              0.80
# 9                  27.81              28.510000   -0.70              0.70

# %%
# Lấy index tương ứng với tập test gốc
test_index = df.index[-len(y_test_seq):]

comparison_df = pd.DataFrame({
    "Ngày": test_index,
    "Nhiệt độ thực tế (°C)": y_test_original.flatten(),
    "Nhiệt độ dự đoán (°C)": y_pred.flatten()
})

comparison_df.set_index("Ngày", inplace=True)
comparison_df.head(20)

print("===== SO SÁNH THEO TỪNG NGÀY =====")
display(comparison_df.round(2).head(20))
# Out:
# ===== SO SÁNH THEO TỪNG NGÀY =====
#             Nhiệt độ thực tế (°C)  Nhiệt độ dự đoán (°C)
# Ngày
# 2013-06-26                  26.93              27.230000
# 2013-06-27                  28.02              28.440001
# 2013-06-28                  27.49              28.080000
# 2013-06-29                  28.11              28.200001
# 2013-06-30                  28.19              28.209999
# 2013-07-01                  27.71              28.100000
# 2013-07-02                  28.26              27.850000
# 2013-07-03                  28.12              27.879999
# 2013-07-04                  27.66              28.459999
# 2013-07-05                  27.81              28.510000
# 2013-07-06                  26.66              28.540001
# 2013-07-07                  25.86              28.420000
# 2013-07-08                  26.80              27.990000
# 2013-07-09                  26.42              27.290001
# 2013-07-10                  26.48              27.760000
# 2013-07-11                  28.29              27.180000
# 2013-07-12                  29.55              26.850000
# 2013-07-13                  29.19              27.790001
# 2013-07-14                  28.48              28.370001
# 2013-07-15                  26.58              28.750000

# %%
mape = np.mean(np.abs((y_test_original - y_pred) / y_test_original)) * 100
print(f"Sai số phần trăm trung bình (MAPE): {mape:.2f}%")
# Out:
# Sai số phần trăm trung bình (MAPE): 3.62%

# %%
model.save("module_cnn_1d.keras")
