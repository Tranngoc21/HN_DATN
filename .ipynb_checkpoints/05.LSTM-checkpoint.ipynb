# %% [markdown]
# ### Xây dựng và huấn luyện mô hình LSTM

# %% [markdown]
# #### Chuẩn bị dữ liệu

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('Data/data_preprocessing.csv', index_col='Date', parse_dates=True)
df.head()
# Out:
#             Precipitation  Temperature  Relative Humidity  Wind Speed
# Date
# 1985-01-01            0.0        24.12              66.46       26.87
# 1985-01-02            0.0        24.27              66.08       26.60
# 1985-01-03            0.1        25.02              61.42       22.44
# 1985-01-04            0.2        25.26              60.54       22.89
# 1985-01-05            0.0        25.05              59.92       24.88

# %%
# Sắp xếp và kiểm tra dữ liệu
df = df.sort_index()

# kiểm tra liên tục thời gian
print(df.index.to_series().diff().value_counts().head())
# Out:
# Date
# 1 days    12204
# Name: count, dtype: int64

# %%
# Chọn biến đầu vào & mục tiêu
features = ['Precipitation', 'Relative Humidity', 'Wind Speed']
target = 'Temperature'

X = df[features]
y = df[target]

# %%
# Chia tập dữ liệu: 70% train, 15% validation, 15% test
total_samples = len(X)
train_size = int(total_samples * 0.70)
val_size = int(total_samples * 0.15)

X_train = X[:train_size]
y_train = y[:train_size]

X_val = X[train_size:train_size + val_size]
y_val = y[train_size:train_size + val_size]

X_test = X[train_size + val_size:]
y_test = y[train_size + val_size:]

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_val shape:", X_val.shape)
print("y_val shape:", y_val.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (8543, 3)
# y_train shape: (8543,)
# X_val shape: (1830, 3)
# y_val shape: (1830,)
# X_test shape: (1832, 3)
# y_test shape: (1832,)

# %%
# Chuẩn hóa dữ liệu
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
X_val_scaled   = scaler_X.transform(X_val)
X_test_scaled  = scaler_X.transform(X_test)

y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1,1))
y_val_scaled   = scaler_y.transform(y_val.values.reshape(-1,1))
y_test_scaled  = scaler_y.transform(y_test.values.reshape(-1,1))

# %%
# Hàm tạo chuỗi dữ liệu > Dự đoán ngày tiếp theo
def create_sequences(X, y, time_step):
    X_seq, y_seq = [], []
    
    for i in range(len(X) - time_step):
        X_seq.append(X[i:i + time_step])
        y_seq.append(y[i + time_step])
        
    return np.array(X_seq), np.array(y_seq)

# %%
# Xác định time_step = 30 
time_step = 30

X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_scaled, time_step)
X_val_seq, y_val_seq     = create_sequences(X_val_scaled, y_val_scaled, time_step)
X_test_seq, y_test_seq   = create_sequences(X_test_scaled, y_test_scaled, time_step)

# %% [markdown]
# #### Xây dựng mô hình

# %%
# Khai báo thư viện
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
print("Train shape:", X_train_seq.shape)
print("Test shape :", X_test_seq.shape)
# Out:
# Train shape: (8513, 30, 3)
# Test shape : (1802, 30, 3)

# %%
# Xây dựng mô hình LSTM
model = Sequential([
    Input(shape=(X_train_seq.shape[1], X_train_seq.shape[2])),
    LSTM(units=50, return_sequences=True),
    LSTM(units=50, return_sequences=False),
    Dropout(0.2),
    Dense(units=1)
])

# %%
# Biên dịch mô hình
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 30, 50)              │          10,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 50)                  │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 31,051 (121.29 KB)
#  Trainable params: 31,051 (121.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Thiết lập callbacks
# checkpoint = ModelCheckpoint('best_lstm_temp_model.h5', save_best_only=True, monitor='val_loss', mode='min')
# early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Huấn luyện mô hình với epochs=50, batch_size=32
history = model.fit(X_train_seq, y_train_seq,
                               epochs=50, 
                               batch_size=32, 
                               validation_data=(X_val_seq, y_val_seq),
                               # callbacks=[checkpoint, early_stop],
                               verbose=1)
# Out:
# Epoch 1/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - loss: 0.0245 - val_loss: 0.0115
# Epoch 2/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0134 - val_loss: 0.0074
# Epoch 3/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0123 - val_loss: 0.0120
# Epoch 4/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0117 - val_loss: 0.0110
# Epoch 5/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0114 - val_loss: 0.0068
# Epoch 6/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0111 - val_loss: 0.0077
# Epoch 7/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0106 - val_loss: 0.0077
# Epoch 8/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0104 - val_loss: 0.0094
# Epoch 9/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0104 - val_loss: 0.0074
# Epoch 10/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0100 - val_loss: 0.0121
# Epoch 11/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0099 - val_loss: 0.0066
# Epoch 12/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0098 - val_loss: 0.0084
# Epoch 13/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0094 - val_loss: 0.0079
# Epoch 14/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0095 - val_loss: 0.0065
# Epoch 15/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0092 - val_loss: 0.0066
# Epoch 16/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0092 - val_loss: 0.0074
# Epoch 17/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0090 - val_loss: 0.0070
# Epoch 18/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0089 - val_loss: 0.0071
# Epoch 19/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0088 - val_loss: 0.0087
# Epoch 20/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0086 - val_loss: 0.0081
# Epoch 21/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0086 - val_loss: 0.0068
# Epoch 22/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0084 - val_loss: 0.0084
# Epoch 23/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0085 - val_loss: 0.0077
# Epoch 24/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0085 - val_loss: 0.0069
# Epoch 25/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0083 - val_loss: 0.0074
# Epoch 26/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0084 - val_loss: 0.0096
# Epoch 27/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0084 - val_loss: 0.0083
# Epoch 28/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0082 - val_loss: 0.0073
# Epoch 29/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0079 - val_loss: 0.0068
# Epoch 30/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0082 - val_loss: 0.0087
# Epoch 31/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0079 - val_loss: 0.0081
# Epoch 32/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0079 - val_loss: 0.0128
# Epoch 33/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0081 - val_loss: 0.0102
# Epoch 34/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0079 - val_loss: 0.0082
# Epoch 35/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - loss: 0.0077 - val_loss: 0.0070
# Epoch 36/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 13s 48ms/step - loss: 0.0077 - val_loss: 0.0063
# Epoch 37/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 13s 49ms/step - loss: 0.0078 - val_loss: 0.0078
# Epoch 38/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 13s 48ms/step - loss: 0.0076 - val_loss: 0.0093
# Epoch 39/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 13s 49ms/step - loss: 0.0077 - val_loss: 0.0100
# Epoch 40/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 13s 49ms/step - loss: 0.0075 - val_loss: 0.0086
# Epoch 41/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 13s 48ms/step - loss: 0.0076 - val_loss: 0.0073
# Epoch 42/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 13s 47ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 43/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 12s 46ms/step - loss: 0.0074 - val_loss: 0.0086
# Epoch 44/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 12s 46ms/step - loss: 0.0075 - val_loss: 0.0065
# Epoch 45/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 12s 46ms/step - loss: 0.0074 - val_loss: 0.0067
# Epoch 46/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 13s 47ms/step - loss: 0.0074 - val_loss: 0.0084
# Epoch 47/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 12s 45ms/step - loss: 0.0074 - val_loss: 0.0072
# Epoch 48/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 12s 46ms/step - loss: 0.0072 - val_loss: 0.0078
# Epoch 49/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 12s 46ms/step - loss: 0.0071 - val_loss: 0.0075
# Epoch 50/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 12s 46ms/step - loss: 0.0072 - val_loss: 0.0066

# %%
# Dự đoán trên tập kiểm tra
y_pred_scaled = model.predict(X_test_seq)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step

# %%
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_test_original = scaler_y.inverse_transform(y_test_seq)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

mse = mean_squared_error(y_test_original, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_original, y_pred)
r2 = r2_score(y_test_original, y_pred)

print("MSE :", mse)
print("RMSE:", rmse)
print("MAE :", mae)
print("R2  :", r2)
# Out:
# MSE : 1.2113620079390934
# RMSE: 1.10061892039847
# MAE : 0.8448595092299246
# R2  : 0.5462284291017258

# %%
 # Vẽ biểu đồ so sánh Thực tế vs Dự đoán
plt.figure(figsize=(10,5))
plt.plot(y_test_original[:200], label="Actual")
plt.plot(y_pred[:200], label="Predicted")
plt.legend()
plt.title("So sánh nhiệt độ thực tế và dự đoán")
plt.show()

# %%
# Vẽ biểu đồ Loss trong quá trình train
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title("Training vs Validation Loss")
plt.show()

# %%
print("===== KẾT QUẢ ĐÁNH GIÁ MÔ HÌNH =====")
print(f"Sai số bình phương trung bình (MSE): {mse:.4f}")
print(f"Căn bậc hai sai số (RMSE): {rmse:.4f} °C")
print(f"Sai số tuyệt đối trung bình (MAE): {mae:.4f} °C")
print(f"Hệ số xác định (R²): {r2:.4f}")
# Out:
# ===== KẾT QUẢ ĐÁNH GIÁ MÔ HÌNH =====
# Sai số bình phương trung bình (MSE): 1.2114
# Căn bậc hai sai số (RMSE): 1.1006 °C
# Sai số tuyệt đối trung bình (MAE): 0.8449 °C
# Hệ số xác định (R²): 0.5462

# %%
comparison_df = pd.DataFrame({
    "Nhiệt độ thực tế (°C)": y_test_original.flatten(),
    "Nhiệt độ dự đoán (°C)": y_pred.flatten()
})

comparison_df["Sai số"] = comparison_df["Nhiệt độ thực tế (°C)"] - comparison_df["Nhiệt độ dự đoán (°C)"]
comparison_df["Sai số tuyệt đối"] = comparison_df["Sai số"].abs()

print("===== BẢNG SO SÁNH GIÁ TRỊ THỰC TẾ VÀ DỰ ĐOÁN =====")
display(comparison_df.round(2).head(10))
# Out:
# ===== BẢNG SO SÁNH GIÁ TRỊ THỰC TẾ VÀ DỰ ĐOÁN =====
#    Nhiệt độ thực tế (°C)  Nhiệt độ dự đoán (°C)  Sai số  Sai số tuyệt đối
# 0                  26.93              27.790001   -0.86              0.86
# 1                  28.02              26.490000    1.53              1.53
# 2                  27.49              27.280001    0.21              0.21
# 3                  28.11              27.559999    0.55              0.55
# 4                  28.19              27.850000    0.34              0.34
# 5                  27.71              27.480000    0.23              0.23
# 6                  28.26              26.910000    1.35              1.35
# 7                  28.12              27.660000    0.46              0.46
# 8                  27.66              27.540001    0.12              0.12
# 9                  27.81              27.230000    0.58              0.58

# %%
# Lấy index tương ứng với tập test gốc
test_index = df.index[-len(y_test_seq):]

comparison_df = pd.DataFrame({
    "Ngày": test_index,
    "Nhiệt độ thực tế (°C)": y_test_original.flatten(),
    "Nhiệt độ dự đoán (°C)": y_pred.flatten()
})

comparison_df.set_index("Ngày", inplace=True)
comparison_df.head(20)

print("===== SO SÁNH THEO TỪNG NGÀY =====")
display(comparison_df.round(2).head(20))
# Out:
# ===== SO SÁNH THEO TỪNG NGÀY =====
#             Nhiệt độ thực tế (°C)  Nhiệt độ dự đoán (°C)
# Ngày
# 2013-06-26                  26.93              27.790001
# 2013-06-27                  28.02              26.490000
# 2013-06-28                  27.49              27.280001
# 2013-06-29                  28.11              27.559999
# 2013-06-30                  28.19              27.850000
# 2013-07-01                  27.71              27.480000
# 2013-07-02                  28.26              26.910000
# 2013-07-03                  28.12              27.660000
# 2013-07-04                  27.66              27.540001
# 2013-07-05                  27.81              27.230000
# 2013-07-06                  26.66              27.309999
# 2013-07-07                  25.86              26.889999
# 2013-07-08                  26.80              26.450001
# 2013-07-09                  26.42              26.889999
# 2013-07-10                  26.48              26.469999
# 2013-07-11                  28.29              26.440001
# 2013-07-12                  29.55              27.049999
# 2013-07-13                  29.19              27.330000
# 2013-07-14                  28.48              27.309999
# 2013-07-15                  26.58              27.180000

# %%
mape = np.mean(np.abs((y_test_original - y_pred) / y_test_original)) * 100
print(f"Sai số phần trăm trung bình (MAPE): {mape:.2f}%")
# Out:
# Sai số phần trăm trung bình (MAPE): 3.20%

# %%
model.save("temperature_lstm_model.keras")
